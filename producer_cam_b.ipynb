# %% [markdown]
# ## <span style="color:#0b486b">Streaming Application</span>
# ### Data Stream Processing (Event Producer B)

# %% [markdown]
# #### Required Imports from the producer_utils.py

# %%
from utils.producer_utils import start_producer

# %% [markdown]
# #### Start to send the event from the camera B

# %%
# Declare the parameter of the start_producer function
path = "data/camera_event_B.csv"
host_ip = "192.168.64.1"
interval = 5
topic = "camera_event_b"
header = {"producer_id": 2, "speed_limit": 110, "dist_next": 1}

# Invoke the function to start the kafka producer
start_producer(host_ip, path, interval, topic, header)
# Out:
# Publishing records...
#
# Publishing batch id 1:
# Data: {'event_id': 'b5b7dae7-3bf9-4f75-aea8-398d3bde3a41', 'batch_id': 1, 'car_plate': 'CJW 924', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:26.029536', 'speed_reading': 156.8} Header: {'producer_id': 2, 'speed_limit': 110, 'dist_next': 1, 'processing_timestamp': '2025-05-28T09:36:54.094956+00:00'}
# Data: {'event_id': '1649c03b-cd6f-47bd-b4f2-c44fcf60524d', 'batch_id': 1, 'car_plate': 'CZ 592', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:26.729115', 'speed_reading': 163.9} Header: {'producer_id': 2, 'speed_limit': 110, 'dist_next': 1, 'processing_timestamp': '2025-05-28T09:36:54.106277+00:00'}
# Data: {'event_id': 'a9c6a4b7-a6b6-4bd7-9719-88bd895814f4', 'batch_id': 1, 'car_plate': 'UTT 229', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:26.887170', 'speed_reading': 134.1} Header: {'producer_id': 2, 'speed_limit': 110, 'dist_next': 1, 'processing_timestamp': '2025-05-28T09:36:54.110701+00:00'}
# ...
